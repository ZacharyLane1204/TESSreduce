# %%
import numpy as np
import matplotlib.pyplot as plt
import tessreduce as tr
# %matplotlib notebook

# %%
tess = tr.tessreduce(tpf='../../SN_individual/grb_test.fits',
                     calibrate=True,quality_bitmask='hard',diagnostic_plot=True)
# Out:
# made reference
# !!!WARNING!!! mask is too dense, lowering mask_scale to 0.5, and raising maglim to 15. Background quality will be reduced.
# made source mask
# calculating background
# adaptive bkg
# background subtracted
# aligning images
# [SepAligner] 7 sources selected for alignment
# <img src="data:image/png;base64,..." width="498">
# <img src="data:image/png;base64,..." width="498">
# <img src="data:image/png;base64,..." width="851">
# !!Re-running for difference image!!
# shifting images
# remade mask
# background
# adaptive bkg
# background correlation correction
# field calibration
# target is above -30 dec, calibrating to PS1 photometry.
# <img src="data:image/png;base64,..." width="498">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="996">
# <img src="data:image/png;base64,..." width="996">

# %%
l, s = tess.diff_lc(phot_method='psf',plot=True)
# Out:
# Optimal PSF shift:  [-0.8        -0.40219973]
# <img src="data:image/png;base64,..." width="996">

# %%
plt.figure()
plt.plot(tess.lc[0],tess.lc[1])
plt.plot(l[0],l[1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
tess.lc[1] += 5

# %%
tess.to_flux()

# %%
m = tess.to_mag()

# %%
plt.figure()
plt.plot(m[1])
plt.gca().invert_yaxis()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 plt.figure()
# ----> 2 plt.plot(m[1])
#       3 plt.gca().invert_yaxis()
#
# NameError: name 'm' is not defined

# %%
# Out:
# (3, 3372)

# %%
import pandas as pd

# %%
l = pd.DataFrame(data=tess.lc.T,columns=['MJD','mJy','e_mJy'])
l.to_csv('',index=False)
# Out:
#                MJD         mJy       e_mJy
# 0     60774.795080   -6.434997  204.177252
# 1     60774.797395   41.964531  223.303671
# 2     60774.799710   24.902475  273.997902
# 3     60774.802025   19.867867  257.708383
# 4     60774.804340    5.679091  236.001919
# ...            ...         ...         ...
# 8364  60802.251069   -2.826644  353.741833
# 8365  60802.253384  -49.028253  363.900099
# 8366  60802.255699  -12.546486  302.314057
# 8367  60802.258014  -38.629566  335.972191
# 8368  60802.260329 -108.062144  304.738969
#
# [8369 rows x 3 columns]

# %%
obs[0][2]
# Out:
# 91

# %%
-2.5*np.log10(flux) + 16.4

# %%
tess.lc[2]
# Out:
# array([28.15623389, 27.60744131, 25.56201544, ...,  6.63977483,
#         3.76882935,  7.28402827])

# %%
obs = tr.spacetime_lookup(268.577,-29.122)
# obs = tr.spacetime_lookup(268.577,-29.122)
# Out:
# !!! WARNING no MJD time specified, using default of 59000
# |   Sector |   Camera |   CCD | Covers   |   Time difference  |
# |          |          |       |          |             (days) |
# |----------+----------+-------+----------+--------------------|
# |       91 |        4 |     3 | False    |            1774.79 |
# |       92 |        1 |     4 | False    |            1802.47 |

# %%
tess = tr.tessreduce(obs_list=obs[0],size=50,
                     calibrate=False,quality_bitmask='hard',align=True,diagnostic_plot=True)
# Out:
# ...
# made reference
# !!!WARNING!!! mask is too dense, lowering mask_scale to 0.5, and raising maglim to 15. Background quality will be reduced.
# made source mask
# calculating background
# adaptive bkg
# background subtracted
# aligning images
# [SepAligner] 6 sources selected for alignment
# <img src="data:image/png;base64,..." width="498">
# <img src="data:image/png;base64,..." width="498">
# <img src="data:image/png;base64,..." width="498">
# !!Re-running for difference image!!
# shifting images
# remade mask
# background
# adaptive bkg
# background correlation correction
# <img src="data:image/png;base64,..." width="996">

# %%
tess.lc.shape
# Out:
# (3, 8369)

# %%
plt.figure()
plt.plot(tess.bkg[:,20,20],'.')
# Out:
# <img src="data:image/png;base64,..." width="640">
