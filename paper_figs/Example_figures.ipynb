# %%
import tessreduce as tr
import matplotlib.pyplot as plt
# %matplotlib notebook
import numpy as np

#plt.rc('text', usetex=True)
#plt.rc('font', family='serif')

fig_width_pt = 240.0  # Get this from LaTeX using \showthe\columnwidth
inches_per_pt = 1.0/72.27               # Convert pt to inches
golden_mean = (np.sqrt(5)-1.0)/2.0         # Aesthetic ratio
fig_width = fig_width_pt*inches_per_pt  # width in inches

# %% [markdown]
# # GRB 191016A

# %%
ra = 30.26933
dec = 24.50988
sector = 17
# This function takes the sky position and downloads the relevant cutout of TESS data
grb = tr.tessreduce(ra,dec,size=90,sector=sector,reduce=True,plot=True)
# Out:
# getting TPF from TESScut
# made reference
# made source mask
# calculating background
# background subtracted
# calculating centroids
# <img src="data:image/png;base64,..." width="498">
# <img src="data:image/png;base64,..." width="498">
# !!Re-running for difference image!!
# shifting images
# remade mask
# background
# Field calibration
# Target is above -30 dec, calibrating to PS1 photometry.
# <img src="data:image/png;base64,..." width="498">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1992">
# <img src="data:image/png;base64,..." width="1992">

# %%
grb.lc[1] -= np.nanmedian(grb.lc[1,280:360])

# %%
grb.to_flux()

# %%
plt.figure(figsize=(1.5*fig_width,1*fig_width))
plt.plot(grb.lc[0]-58772,grb.lc[1],'k.')
plt.ylim(-.2,3.5)
plt.xlim(-.5,1)
plt.ylabel('Flux (mJy)',fontsize=15)
plt.xlabel(r'Time $(\rm MJD-58772)$',fontsize=15)
plt.annotate('GRB 191016A\n',(.05,.8),xycoords='axes fraction',fontsize=12)
plt.savefig('grb191016a.pdf', bbox_inches = "tight")
# Out:
# <img src="data:image/png;base64,..." width="498">

# %%
grb.to_mag()

# %%
grb.plotter()
# Out:
# <img src="data:image/png;base64,..." width="498">

# %% [markdown]
# # SN 2018emt

# %%
obj = tr.sn_lookup('sn2018emt')
# Out:
# |   Sector | Covers   |   Time difference  |
# |          |          |             (days) |
# |----------+----------+--------------------|
# |        1 | True     |                  0 |
# |       28 | False    |                729 |
# |       68 | False    |               1823 |

# %%
emt = tr.tessreduce(obs_list=obj,reduce=True,plot=True)
# Out:
# getting TPF from TESScut
# made reference
# made source mask
# calculating background
# background subtracted
# aligning images
# !!Re-running for difference image!!
# shifting images
# remade mask
# background
# background correlation correction
# field calibration
# target is above -30 dec, calibrating to PS1 photometry.
# <img src="data:image/png;base64,..." width="996.3636147680367">

# %%
emt.lc[1] -= np.nanmedian(emt.lc[1,:100])
emt.to_flux()

# %%
plt.figure()
plt.plot(emt.lc[0],emt.lc[1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
emt.plotter()
plt.ylim(-.1,.9)
#plt.xlim(59255,59280)
plt.annotate('SN 2018emt\nType II',(.05,.8),xycoords='axes fraction',fontsize=12)
plt.savefig('sn2018emt.pdf', bbox_inches = "tight")

# %% [markdown]
# # ASASSN-19bt

# %%
obj = tr.sn_lookup('ASASSN-19bt')
# Out:
# |   Sector | Covers   |   Time difference  |
# |          |          |             (days) |
# |----------+----------+--------------------|
# |        1 | False    |               -160 |
# |        2 | False    |               -131 |
# |        3 | False    |               -103 |
# |        4 | False    |                -75 |
# |        5 | False    |                -49 |
# |        7 | True     |                  0 |
# |        8 | False    |                  4 |
# |        9 | False    |                 30 |
# |       10 | False    |                 56 |
# |       11 | False    |                 83 |
# |       12 | False    |                112 |
# |       13 | False    |                141 |
# |       27 | False    |                522 |
# |       28 | False    |                548 |
# |       29 | False    |                575 |
# |       30 | False    |                602 |
# |       31 | False    |                631 |
# |       32 | False    |                660 |
# ...

# %%
obj
# Out:
# [[105.04810833333333, -66.04003888888889, 1, False],
#  [105.04810833333333, -66.04003888888889, 2, False],
#  [105.04810833333333, -66.04003888888889, 3, False],
#  [105.04810833333333, -66.04003888888889, 4, False],
#  [105.04810833333333, -66.04003888888889, 5, False],
#  [105.04810833333333, -66.04003888888889, 7, True],
#  [105.04810833333333, -66.04003888888889, 8, False],
#  [105.04810833333333, -66.04003888888889, 9, False],
#  [105.04810833333333, -66.04003888888889, 10, False],
#  [105.04810833333333, -66.04003888888889, 11, False],
#  [105.04810833333333, -66.04003888888889, 12, False],
#  [105.04810833333333, -66.04003888888889, 13, False],
#  [105.04810833333333, -66.04003888888889, 27, False],
#  [105.04810833333333, -66.04003888888889, 28, False],
#  [105.04810833333333, -66.04003888888889, 29, False],
#  [105.04810833333333, -66.04003888888889, 30, False],
#  [105.04810833333333, -66.04003888888889, 31, False],
#  [105.04810833333333, -66.04003888888889, 32, False],
# ...

# %%
tr.tessreduce().get_TESS(ra = 105.04810833333333, dec = -66.04003888888889,Sector=5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-90fae8cb384d> in <module>
# ----> 1 tr.tessreduce().get_TESS(ra = 105.04810833333333, dec = -66.04003888888889,Sector=6)
#
# ~/miniconda3/lib/python3.7/site-packages/tessreduce/tessreduce.py in get_TESS(self, ra, dec, name, Size, Sector, quality_bitmask, cache_dir)
#     666                         Size = self.size
#     667
# --> 668                 tpf = tess.download(quality_bitmask=quality_bitmask,cutout_size=Size,download_dir=cache_dir)
#     669
#     670                 self.tpf  = tpf
#
# ~/miniconda3/lib/python3.7/site-packages/lightkurve/utils.py in wrapper(*args, **kwargs)
#     553             sys.stdout = devnull
#     554             try:
# --> 555                 return f(*args, **kwargs)
#     556             # restore to default
#     557             finally:
#
# ...

# %%
import lightkurve as lk
import astropy.units as u

# %%
c = tr.SkyCoord(ra=float(105.04810833333333)*u.degree, dec=float(-66.04003888888889) *
                u.degree, frame='icrs')
a = lk.search_tesscut(c,sector=7)

# %%
b = a.download()

# %%
bt = tr.tessreduce(obs_list=obj,reduce=True,plot=True,size=10)
# Out:
# getting TPF from TESScut
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-1ff254de4935> in <module>
# ----> 1 bt = tr.tessreduce(obs_list=obj,reduce=True,plot=True,size=10)
#
# ~/miniconda3/lib/python3.7/site-packages/tessreduce/tessreduce.py in __init__(self, ra, dec, name, obs_list, tpf, size, sector, reduce, align, parallel, diff, plot, savename, quality_bitmask, verbose, cache_dir, calibrate)
#     612                         if self.verbose>0:
#     613                                 print('getting TPF from TESScut')
# --> 614                         self.get_TESS(quality_bitmask=quality_bitmask,cache_dir=cache_dir)
#     615
#     616                 self.ground = ground(ra = self.ra, dec = self.dec)
#
# ~/miniconda3/lib/python3.7/site-packages/tessreduce/tessreduce.py in get_TESS(self, ra, dec, name, Size, Sector, quality_bitmask, cache_dir)
# ...

# %%
bt.plotter()
plt.annotate('SN 2018emt\ntype II',(.05,.8),xycoords='axes fraction',fontsize=12)
# Out:
# <img src="data:image/png;base64,..." width="498">

# %% [markdown]
# # SDSS J122740+513925

# %%
dn = tr.tessreduce(ra=186.9201047,dec=51.6569499,sector=15,plot=True,reduce=True)
# Out:
# getting TPF from TESScut
# made reference
# made source mask
# calculating background
# background subtracted
# calculating centroids
# <img src="data:image/png;base64,..." width="498">
# <img src="data:image/png;base64,..." width="498">
# !!Re-running for difference image!!
# shifting images
# remade mask
# background
# Field calibration
# Target is above -30 dec, calibrating to PS1 photometry.
# <img src="data:image/png;base64,..." width="498">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="1992">
# <img src="data:image/png;base64,..." width="1992">

# %%
dn.lc[1] -= np.nanmedian(dn.lc[1,:50])
dn.to_flux()

# %%
dn.plotter()
# Out:
# <img src="data:image/png;base64,..." width="498">

# %%
plt.figure(figsize=(1.5*fig_width,1*fig_width))
plt.plot(dn.lc[0],dn.lc[1],'k.',ms=5)
plt.ylim(-.1,4)
plt.xlim(58710.5,58730)
plt.annotate('SDSS J122740.83+513925.0\nSU UMa Type DN',(.45,.8),xycoords='axes fraction',fontsize=12)
plt.locator_params(axis='x', nbins=5)
plt.ylabel('Flux (mJy)',fontsize=15)
plt.xlabel(r'Time (MJD)',fontsize=15)
plt.savefig('DN.pdf', bbox_inches = "tight")
# Out:
# <img src="data:image/png;base64,..." width="498">

# %%
ll = dn.to_lightkurve()

# %%
per = ll.to_periodogram()

# %%
p = find_peaks(per.power,prominence=5e-5)[0]
plt.figure()
plt.plot(per.frequency,per.power)
plt.plot(per.frequency[p],per.power[p],'r.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.diff(per.frequency)[p]
# Out:
# <Quantity [0.0076924, 0.0076924, 0.0076924, 0.0076924, 0.0076924,
#            0.0076924, 0.0076924, 0.0076924, 0.0076924, 0.0076924,
#            0.0076924, 0.0076924] 1 / d>

# %%
1/per.frequency[p]
# Out:
# <Quantity [32.49961853, 12.99984741,  8.12490463,  6.19040353,  4.99994131,
#             4.06245232,  3.51347227,  3.09520176,  2.76592498,  2.06346784,
#             0.0646437 ,  0.06295326] d>

# %%
from scipy.signal import find_peaks

# %%
find_peaks(per.power)
# Out:
# (array([   3,    9,   15,   20,   25,   31,   36,   41,   46,   51,   57,
#           62,   67,   72,   77,   83,   88,   93,   98,  103,  108,  114,
#          120,  125,  131,  136,  141,  146,  151,  156,  161,  166,  172,
#          177,  181,  186,  191,  196,  202,  207,  212,  217,  222,  228,
#          234,  240,  245,  250,  255,  261,  266,  271,  275,  281,  287,
#          292,  297,  303,  311,  317,  324,  331,  336,  340,  345,  351,
#          356,  361,  367,  372,  376,  381,  386,  391,  396,  401,  406,
#          411,  416,  425,  431,  436,  441,  446,  451,  456,  461,  466,
#          471,  476,  481,  485,  491,  496,  501,  506,  511,  516,  521,
#          527,  532,  538,  550,  556,  561,  567,  575,  580,  586,  591,
#          597,  601,  610,  616,  622,  627,  634,  640,  646,  654,  660,
#          666,  676,  681,  687,  696,  702,  710,  725,  731,  736,  741,
#          747,  755,  761,  767,  776,  785,  790,  796,  802,  808,  815,
# ...

# %%
1/15.469
# Out:
# 0.06464541987200208

# %%
per.frequency_at_max_power
# Out:
# <Quantity 0.03076959 1 / d>

# %% [markdown]
# # SN 2019esa

# %%
obj = tr.sn_lookup('sn2019esa')
# Out:
# |   Sector | Covers   |   Time difference  |
# |          |          |             (days) |
# |----------+----------+--------------------|
# |        3 | False    |               -200 |
# |        6 | False    |               -119 |
# |        7 | False    |                -93 |
# |       10 | False    |                -14 |
# |       11 | True     |                  0 |
# |       12 | False    |                 15 |
# |       13 | False    |                 44 |
# |       27 | False    |                425 |
# |       30 | False    |                505 |
# |       33 | False    |                591 |
# |       36 | False    |                671 |
# |       37 | False    |                697 |
# |       38 | False    |                723 |
# |       39 | False    |                751 |

# %%
esa = tr.tessreduce(obs_list=obj,reduce=True,plot=True)
# Out:
# getting TPF from TESScut
# made reference
# !!!WARNING!!! mask is too dense, lowering mask_scale to 0.5, and raising maglim to 15. Background quality will be reduced.
# made source mask
# calculating background
# background subtracted
# calculating centroids
# <img src="data:image/png;base64,..." width="498">
# !!Re-running for difference image!!
# shifting images
# remade mask
# background
# Field calibration
# Target is too far south with Dec = -76.412 for PS1 photometry. Can't calibrate at this time, so using zp = 20.44.
# <img src="data:image/png;base64,..." width="996">

# %%
esa.lc[1] -= np.nanmedian(esa.lc[1,:300])
esa.to_flux()

# %%
esa.plotter()
plt.annotate('SN 2018emt\ntype II',(.05,.8),xycoords='axes fraction',fontsize=12)
# Out:
# <img src="data:image/png;base64,..." width="498">

# %%
obj = tr.sn_lookup('sn2020yzo')
# Out:
# |   Sector | Covers   |   Time difference  |
# |          |          |             (days) |
# |----------+----------+--------------------|
# |        1 | False    |               -807 |
# |        2 | False    |               -778 |
# |        3 | False    |               -750 |
# |        4 | False    |               -722 |
# |        5 | False    |               -696 |
# |        6 | False    |               -669 |
# |        7 | False    |               -643 |
# |        8 | False    |               -617 |
# |        9 | False    |               -591 |
# |       10 | False    |               -564 |
# |       11 | False    |               -535 |
# |       12 | False    |               -506 |
# |       13 | False    |               -477 |
# |       27 | False    |                -99 |
# |       28 | False    |                -72 |
# |       29 | False    |                -45 |
# |       30 | False    |                -16 |
# |       31 | True     |                  0 |
# ...

# %%
yzo = tr.tessreduce(obs_list=obj,reduce=True,plot=True)#,savename='sn2020yzo')
# Out:
# getting TPF from TESScut
# made reference
# !!!WARNING!!! mask is too dense, lowering mask_scale to 0.5, and raising maglim to 15. Background quality will be reduced.
# made source mask
# calculating background
# background subtracted
# aligning images
# !!Re-running for difference image!!
# shifting images
# remade mask
# background
# background correlation correction
# field calibration
# target is below -30 dec, calibrating to SkyMapper photometry.
# <img src="data:image/png;base64,..." width="996.3636147680367">

# %%
plt.figure()
plt.plot(yzo.lc[0],yzo.lc[1] - a[0][1])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
a = yzo.diff_lc(phot_method='psf',plot=True)
# Out:
# <img src="data:image/png;base64,..." width="996.3636147680367">

# %%
l, ll = yzo.diff_lc(x=75,y=54)
# Out:
# <img src="data:image/png;base64,..." width="996">

# %%
l.shape
# Out:
# (3, 3445)

# %%
ll = yzo.to_lightkurve(lc=l)

# %%
ll.to_periodogram().plot()
# Out:
# <img src="data:image/png;base64,..." width="848">
# <AxesSubplot:xlabel='Frequency [$\\mathrm{\\frac{1}{d}}$]', ylabel='Power [$\\mathrm{\\frac{e^{-}}{s}}$]'>

# %%
yzo.wcs.all_pix2world(75,54,0)
# Out:
# [array(101.0364766), array(-72.41584173)]

# %%
a = bt.mask

# %%
plt.figure()
plt.imshow((a ==4))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
obj = tr.sn_lookup('sn2020cdj')
# Out:
# |   Sector | Covers   |   Time difference  |
# |          |          |             (days) |
# |----------+----------+--------------------|
# |       14 | False    |               -177 |
# |       15 | False    |               -150 |
# |       16 | False    |               -124 |
# |       17 | False    |                -98 |
# |       18 | False    |                -73 |
# |       20 | False    |                -18 |
# |       21 | True     |                  0 |
# |       22 | False    |                 10 |
# |       23 | False    |                 39 |
# |       24 | False    |                 68 |
# |       25 | False    |                 95 |
# |       26 | False    |                121 |
# |       40 | False    |                502 |
# |       41 | False    |                531 |
# |       47 | False    |                691 |
# |       48 | False    |                720 |
# |       50 | False    |                777 |
# |       51 | False    |                804 |
# ...

# %%
bt = tr.tessreduce(obs_list=obj,reduce=False,plot=True,savename='sn2020cdj',size=20)
# Out:
# getting TPF from TESScut

# %%
bt.tpf.ccd
# Out:
# 3

# %%
bt = tr.tessreduce(obs_list=obj,reduce=True,plot=True,savename='sn2020cdj')
# Out:
# getting TPF from TESScut
# made reference
# made source mask
# calculating background
# background subtracted
# calculating centroids
# <img src="data:image/png;base64,..." width="498">
# <img src="data:image/png;base64,..." width="498">
# !!Re-running for difference image!!
# shifting images
# remade mask
# background
# Field calibration
# Target is above -30 dec, calibrating to PS1 photometry.
# <img src="data:image/png;base64,..." width="498">
# !!!!
# !!!!! 13.038342895507814
# ????? 13.038342895507814
# !!!!! 13.020345869064332
# ????? 13.020345869064332
# !!!!! 13.983836474418641
# ????? 13.983836474418641
# !!!!! 13.217538299560548
# ????? 13.217538299560548
# !!!!! 13.670375051498414
# ????? 13.670375051498414
# !!!!! 13.306804599761964
# ????? 13.306804599761964
# !!!!! 13.564899864196779
# ????? 13.564899864196779
# !!!!! 12.93604642391205
# ????? 12.93604642391205
# !!!!! 12.777880730628969
# ????? 12.777880730628969
# !!!!! 11.272850337028505
# ????? 11.272850337028505
# ...

# %% [markdown]
# # SN2018fub

# %%
obj = tr.sn_lookup('sn2020adw')
# This function takes the sky position and downloads the relevant cutout of TESS data
grb = tr.tessreduce(obs_list=obj,plot=True,savename='sn2018fub')
# Out:
# |   Sector | Covers   |   Time difference  |
# |          |          |             (days) |
# |----------+----------+--------------------|
# |       14 | False    |               -154 |
# |       20 | True     |                  0 |
# |       21 | False    |                  5 |
# |       40 | False    |                525 |
# |       41 | False    |                554 |
# |       47 | False    |                714 |
# |       53 | False    |                879 |
# |       60 | False    |               1072 |
# |       74 | False    |               1448 |
# getting TPF from TESScut
# made reference
# made source mask
# calculating background
# background subtracted
# aligning images
# !!Re-running for difference image!!
# shifting images
# remade mask
# background
# background correlation correction
# field calibration
# target is above -30 dec, calibrating to PS1 photometry.
# <img src="data:image/png;base64,..." width="996.3636147680367">

# %%
grb.lc[1] -= np.nanmedian(grb.lc[1,:400])
grb.plotter(ground=True)
plt.xlim(58840,58900)
plt.ylim(-.05,.22)
ax = plt.gca()
plt.annotate('SN 2020adw\nType Ia',(.05,.8),xycoords='axes fraction',fontsize=12)
plt.savefig('sn2020adw.pdf', bbox_inches = "tight")
# Out:
# <img src="data:image/png;base64,..." width="498.1818073840183">

# %%
plt.figure()
plt.plot(grb.bkg[:,10,45],'.')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
import tessreduce as tr
obj = tr.sn_lookup('sn2018fub')

# %% [markdown]
# # Var

# %%
ra = 299.44151147
dec = 61.93009011
obj = tr.spacetime_lookup(ra=ra,dec=dec)
# Out:
# !!! WARNING no MJD time specified, using default of 59000
# |   Sector | Covers   |   Time difference  |
# |          |          |             (days) |
# |----------+----------+--------------------|
# |       14 | False    |               -290 |
# |       15 | False    |               -263 |
# |       16 | False    |               -237 |
# |       17 | False    |               -211 |
# |       18 | False    |               -186 |
# |       21 | False    |               -103 |
# |       24 | False    |                -18 |
# |       41 | False    |                418 |
# |       47 | False    |                578 |
# |       48 | False    |                607 |
# |       51 | False    |                691 |
# |       54 | False    |                769 |
# |       55 | False    |                796 |

# %%
# This function takes the sky position and downloads the relevant cutout of TESS data
var = tr.tessreduce(obs_list=obj[6],reduce=True,plot=True,savename='variable',size=50)
# Out:
# getting TPF from TESScut
# made reference
# !!!WARNING!!! mask is too dense, lowering mask_scale to 0.5, and raising maglim to 15. Background quality will be reduced.
# made source mask
# calculating background
# background subtracted
# calculating centroids
# <img src="data:image/png;base64,..." width="374.9999944120646">
# !!Re-running for difference image!!
# shifting images
# remade mask
# background
# Field calibration
# Target is above -30 dec, calibrating to PS1 photometry.
# <img src="data:image/png;base64,..." width="374.9999944120646">
#           RAJ2000    DEJ2000               objID    f_objID  Qual  e_RAJ2000  \
# 1933   299.556706  61.824682  182192995567500377  503635968    60     0.0019
# 1958   299.562724  61.823462  182182995627228919  503635968    60     0.0024
# 1980   299.484353  61.819771  182182994843824478  503635968    60     0.0043
# 2004   299.487366  61.815776  182172994873869692  503635968    60     0.0048
# ...

# %%
obs = tr.spacetime_lookup('10:25:30.98', '+60:13:38.6')
# Out:
# !!! WARNING no MJD time specified, using default of 59000
# |   Sector |   Camera |   CCD | Covers   |   Time difference  |
# |          |          |       |          |             (days) |
# |----------+----------+-------+----------+--------------------|
# |       21 |        2 |     2 | False    |               -103 |
# |       48 |        2 |     2 | False    |                607 |
# |       74 |        1 |     4 | False    |               1312 |
# |       75 |        1 |     3 | False    |               1339 |

# %%
t = tr.tessreduce(obs_list=obs[2],calibrate=False)
# Out:
# getting TPF from TESScut
# made reference
# made source mask
# calculating background
# background subtracted
# aligning images
# !!Re-running for difference image!!
# shifting images
# remade mask
# background
# background correlation correction
# <img src="data:image/png;base64,..." width="136.36363340803422">
